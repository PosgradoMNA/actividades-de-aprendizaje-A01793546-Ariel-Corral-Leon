# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01793546-Ariel-Corral-Leon/blob/main/Copy_of_Data_Analysis_with_Python_2nd_Course_Progress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tec.jpeg](data:image/jpeg;base64,...)
#
#
# #IBM: DA0101EN Data Analysis with Python
#
# ###Curso de Analisis de datos con Python
#
# #### Nombre: ***José Ariel Corral Leon***
# #### Matricula: ***A01793546***

# %% [markdown]
# August  7, 2017
#
# - Beta  Module 1 and 2  are available.
#  - Module 1 will cover: understanding a domain, understanding a dataset, overview of Python packages for data science Data Acquisition and Obtain basic insight from datasets.
#  - Module 2 will cover: Identify and handle missing values, data formatting, data normalization, data binning and Indicator variables.
#
# September  1, 2017
#
# - Full Beta everything is available.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Librerias utilzadas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Módulo #1 - Introducción
#
# Durante el curso podremos realizar algunos puntos a continuación:
#
#
# | Elementos a considerar |
# |---------|
# | 1.- Problemas que requieren analizis de datos |
# | 2.- Como se analizan las bases de datos en Python |
# | 3.- Los paquetes con los que se analizan los datos de Python |
# | 4.- Importanto y exportando información |
# | 5.- Puntos basicos sobre el manejo de "Data Sets" |

# %% [markdown]
# Dentro de los puntos basicos para el análisis de datos debemos de considerar:
# Tipos de datos
#
#
# | Señales basicas para el analisis de información  |
# |------|
# | Variables excluidas  |
# | Verificación de datos  |
# | Distribución de datos  |
# | Localizar errores en los datos  |

# %% [markdown]
# Hay diferentes formas de la itnerpretación de los datos segun el typo de datos y quien lo interprete:
#
#
# | Tipo de datos de PANDAS  |  Tipo de dato  |  Descripción  |
# | --- | --- | --- |
# | Objeto  | String  | Numeros y "strings"  |
# | int64  | int | Caracteres numéricos  |
# | float64  | float  | Caracteres numéricos con puntos decimales |
# | datetime64, timedelta NS  | N/A (pero se puede determinar por modulo de
# tiempo segun las librerías)  | información de tiempo y fecha  |
#
#
# **df.dtypes**  = muestra el tipo de datos que tenemos en cada segmento
#
# **df.describe** = muestra una tabla de detalles con estimaciones matematicas para poder identificar anormalidades
# **df.describe(include="all")** = incluye todas las características del Dataframe
# **df.info() =  muestra toda la tabla resumida

# %% [markdown]
# ###Entrega de Examen y calificación

# %% [markdown]
# ![Captura desde 2022-10-09 19-28-02.png](data:image/png;base64,...)

# %% [markdown]
# Los errores en el examen fueron los siguientes:
#
# ![Captura desde 2022-10-09 19-29-33.png](data:image/png;base64,...)![Captura desde 2022-10-09 19-29-21.png](data:image/png;base64,...)

# %% [markdown]
# ## Módulo #2 - Manejo de datos

# %% [markdown]
#  Para poder realizar el manejo de datos de forma correcta tomaremos en cuenta los siguientes aspectos:
#
#
#  | Características de la informacion y su manejo |
#  ---
#  Pre - Procesamiento
#  Resolución de datos faltantes
#  Formateo de valores
#  Normalización de datos
#  Binnado con python
#  Migrando categorías de variables a cuantitativas

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.rename(columns={'a':'b'})
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df['A'].std()
# Out:
# 1.0

# %%
df_Price= pd.DataFrame({"Prices":[12345,45678,46897,42516,13468]})
df_Price
# Out:
#    Prices
# 0   12345
# 1   45678
# 2   46897
# 3   42516
# 4   13468

# %%
binsgroup_names=["Low","Med","High"]

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6],"C":["Muestra","Escondido","Muestra"]})
df
# Out:
#    A  B          C
# 0  1  4    Muestra
# 1  2  5  Escondido
# 2  3  6    Muestra

# %% [markdown]
# ###Pre-Procesamiento:
# Durante este procesamiento se debe de tener en cuenta que se deben de aprender a manipular los "0s" ó valores vacios

# %% [markdown]
# ###Resolución de datos faltantes:

# %% [markdown]
# Tenemos que identificar si tenemos campos vacios, faltantes, en blancom, NaN o bien con un "?"

# %% [markdown]
# ###Formateo de valores:

# %% [markdown]
# ###Normalización de datos:

# %% [markdown]
# ###Resolución de datos faltantes:

# %% [markdown]
# Los datos pueden normalizarse, estandarizarse o dejarse así, todo depende de nuestras necesidades
#
# La idea de normalizar es para establecer la misma metrica para todos los valores para no tener diferentes magnitudes y hay diferentes metodos de porder hacerlo

# %% [markdown]
# ###Agrupamiento:

# %%
from pandas.core.indexes.base import default_pprint
bins = np.linspace(min(df_Price["Prices"]),max(df_Price["Prices"]),3)
bins
# Out:
# array([12345., 29621., 46897.])

# %% [markdown]
# ###Convirtiendo variables cualitativas a variables cuantitativas:

# %%
pd.get_dummies(df['C'])
# Out:
#    Escondido  Muestra
# 0          0        1
# 1          1        0
# 2          0        1

# %% [markdown]
# ###Entrega de examen y calificación

# %% [markdown]
# ![Module2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Módulo #3 - Exploración de datos

# %% [markdown]
# EDA por sus siglas en ingles (Exploratory Data Analysis)
#
# Comprende los siguientes elementos en el analisis de información
# * Sumarizar las características de la información
# * Obtener un buen entendimiento de la base de datos
# * Mostrar la relación que existen entre las variables
# * Extracción de la información impórtante
#
#
# Objetivos del módulo:
#
# * Estandística descriptiva
# * Agrupaciones por
# * ANOVA
# * Correlacion
# * Correlacion estadística

# %% [markdown]
# ####Estadísticas Descriptivas:
# * Describen funciones de la informacion
# * Proveen un resumen sobre la muestra y la medida de la información
# *

# %%
df
# Out:
#    A  B          C
# 0  1  4    Muestra
# 1  2  5  Escondido
# 2  3  6    Muestra

# %%
df.describe()
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %%
df.value_counts()
# Out:
# A  B  C
# 1  4  Muestra      1
# 2  5  Escondido    1
# 3  6  Muestra      1
# dtype: int64

# %% [markdown]
# Parte de la estadística descriptiva es el poder identificar que datos estan posicionados en que segmento y con ello poder demostrar graficamente nuestra informacion y su respectiva distribución:
# ![Boxplots.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Otro metodo de poder describir nuestra estadística es con "Scatterplot" que nos ayuda a demostrar las relaciones que existen entre variables:
# ![Scatter_Plot.jpg](data:image/jpeg;base64,...)

# %%
Corte_de_curso = 'https://courses.cognitiveclass.ai/courses/course-v1:CognitiveClass+DA0101EN+v1/courseware/bab98e3892694bd5aae8d0f7dc111a30/aa87d46c21004d36a9800c315c6dc445/?child=first'

# %%
Corte_de_curso
# Out:
# 'https://courses.cognitiveclass.ai/courses/course-v1:CognitiveClass+DA0101EN+v1/courseware/bab98e3892694bd5aae8d0f7dc111a30/aa87d46c21004d36a9800c315c6dc445/?child=first'

# %% [markdown]
# #### Agrupaciones en Python:

# %% [markdown]
# ## Módulo #4 - Desarrollo de modelos

# %% [markdown]
# ## Módulo #5 - Evaluación de modelos
